# %%
import matplotlib.pyplot as plt
image = plt.imread("ImgData/hestain.png")
plt.imshow(image)

# %%
image2 = image.reshape(-1,3)
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3).fit(image2)
segment = kmeans.cluster_centers_[kmeans.labels_].reshape(image.shape)
print(kmeans.cluster_centers_)
print(kmeans.labels_)
# plt.imshow(segment)
# Out:
# [[0.86450803 0.6863991  0.9830733 ]
#  [0.44553596 0.285339   0.6976119 ]
#  [0.7332744  0.43824762 0.87991726]]
# [1 2 2 ... 1 1 1]
